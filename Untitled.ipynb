# %%
import pandas as pd
from matplotlib import pyplot # For understanding dataset
from pandas.plotting import scatter_matrix # For understanding dataset
train_file_path = "/home/p/Desktop/csitml/train.csv"

train_data = pd.read_csv (train_file_path, index_col="PassengerId")

# %%
train_data.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f94fe3a7358>,
# ...
#       dtype=object)

# %%
train_data.plot(kind='density', subplots=True, layout=(3,3), sharex=False)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f94fb062240>,
# ...
#       dtype=object)

# %%
train_data.plot(kind = 'box', subplots = True, layout = (3,3), sharex = False,sharey = False)
# Out:
# Survived       AxesSubplot(0.125,0.657941;0.227941x0.222059)
# Pclass      AxesSubplot(0.398529,0.657941;0.227941x0.222059)
# Age         AxesSubplot(0.672059,0.657941;0.227941x0.222059)
# SibSp          AxesSubplot(0.125,0.391471;0.227941x0.222059)
# Parch       AxesSubplot(0.398529,0.391471;0.227941x0.222059)
# Fare        AxesSubplot(0.672059,0.391471;0.227941x0.222059)
# dtype: object

# %%
scatter_matrix (train_data)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f94fa93c978>,
# ...
#       dtype=object)

# %%
pyplot.show()

# %%
train_data
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# 6                   0       3
# 7                   0       1
# 8                   0       3
# 9                   1       3
# 10                  1       2
# 11                  1       3
# 12                  1       1
# 13                  0       3
# 14                  0       3
# 15                  0       3
# 16                  1       2
# 17                  0       3
# 18                  1       2
# 19                  0       3
# 20                  1       3
# 21                  0       2
# 22                  1       2
# 23                  1       3
# 24                  1       1
# 25                  0       3
# 26                  1       3
# 27                  0       3
# 28                  0       1
# 29                  1       3
# ...

# %%
train_data_columns = list (train_data.columns)

# %%
train_data_columns.remove ("Survived")

# %%
train_data_columns
# Out:
# ['Pclass',
#  'Name',
#  'Sex',
#  'Age',
#  'SibSp',
#  'Parch',
#  'Ticket',
#  'Fare',
#  'Cabin',
#  'Embarked']

# %%
for column in train_data_columns:
    train_data.plot(kind='bar', x=column, y="Survived", figsize=(10,5))

# %%
train_data.plot (kind='scatter', x='Fare', y='Survived')
